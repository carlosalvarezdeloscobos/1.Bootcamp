# %%
#PYTHON API CHALLENGE

# %%
#INDEX

#dependencies

#Part I - WeatherPy
#SECTION I: Create a list of cities with citypi
#SECTION II: request info from openweather
#SECTION III: SCATTERPLOTS
#SECTION IV LINEAR REGRESSIONS

#Part II - VacationsPy

#SECTION 1 : HEAT MAP
#SECTION 2: FIND IDEAL CONDITIONS 
#SECTION 3: SEARCH FOR HOTEL
#SECTION 4: HOTELS & HUMIDITY

# %%
#DEPENDENCIES

import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from pprint import pprint
from scipy import stats
import random
from random import randrange
#from numpy import random

# %%
# Part I - WeatherPy
#Overal objective: observe if temperture is hotter closer to the equator.

# %%
#SECTION I: Create a list of cities with citypi

# %%
# 1.1 Create a list o lists of +500 cities that has the system coordinates
#Then the sample of cities have to be distributed from various ranges of latitude

#northhemisphere cities
NH=[]
#south hemisphere cities
SH=[]


#Create a loop with citypi to create random city lists

for x in range(0,501):
    a= randrange(0,60)
    b= randrange(-180,180)
    mity =citipy.nearest_city(a,b)
    NH.append(mity.city_name)

for y in range(0,501):
    c= randrange(-60,-1)
    d= randrange(-180,180)
    dity =citipy.nearest_city(c,d)
    SH.append(dity.city_name)

# %%
#SECTION II: request info from openweather
#NH

# %%
# 2.1 Bring information from open weather

#!!! config key!!!!!
from config import api_key


url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
# 2.2 Create empty list to gather data SOUTH
latitude_south = []
longitude_south=[]
temperature_south = []
cloudiness_south =[]
windspeed_south=[]
humidity_south=[]

# Loop through the list of list_cities and perform a request 
for x in SH:
    responseS = requests.get(query_url + x).json()
    try:
        latitude_south.append(responseS['coord']['lat'])
        longitude_south.append(responseS['coord']['lon'])
        temperature_south.append(responseS['main']['temp'])
        cloudiness_south.append(responseS['clouds']['all'])
        windspeed_south.append(responseS['wind']['speed'])
        humidity_south.append(responseS['main']['humidity'])

        
    except (KeyError, IndexError):
        next

# %%
lat_lon_south={ 
    "lat": latitude_south,
    "lon": longitude_south,
    "temp": temperature_south, 
    "cloud": cloudiness_south,
    "wind": windspeed_south,
    "humidity": humidity_south
}
latlon_south= pd.DataFrame(lat_lon_south)
latlon_south.head()
# Out:
#        lat       lon   temp  cloud  wind  humidity
# 0  -8.7386   24.9906  18.87    100  0.99        92
# 1  -7.9562   38.9716  24.01     88  1.37        94
# 2 -21.1500  149.2000  31.49     43  4.63        55
# 3 -23.1203 -134.9692  26.74     93  5.05        74
# 4   5.4112  100.3354  26.06     20  1.54        73

# %%
#2.3 Create empty list to gather data NORTH
latitude_north = []
temperature_north = []
cloudiness_north =[]
windspeed_north=[]
humidity_north=[]
longitude_north=[]

# Loop through the list of list_cities and perform a request 
for x in NH:
    responseN = requests.get(query_url + x).json()
    try:
        latitude_north.append(responseN['coord']['lat'])
        longitude_north.append(responseS['coord']['lon'])
        temperature_north.append(responseN['main']['temp'])
        cloudiness_north.append(responseN['clouds']['all'])
        windspeed_north.append(responseN['wind']['speed'])
        humidity_north.append(responseN['main']['humidity'])
    except (KeyError, IndexError):
        next

# %%
# 2.4 create a data frame from cities, lat, and temp SOUTH
lat_lon_north = {
    
    "lat": latitude_north,
    "lon": longitude_north,
    "temp": temperature_north,
    "cloud": cloudiness_north,
    "wind": windspeed_north,
    "humidity": humidity_north
}
latlon_north = pd.DataFrame(lat_lon_north)
latlon_north.head()
# Out:
#        lat      lon   temp  cloud  wind  humidity
# 0  50.2696 -90.3518 -14.50      3  0.42        74
# 1  64.3833 -90.3518 -11.62    100  7.62        91
# 2  33.0833 -90.3518  13.00     20  1.03        88
# 3  59.7035 -90.3518  -9.91     75  3.00        86
# 4  17.9583 -90.3518  20.99      0  2.73        65

# %%
#MERGE SOUTH AND NORTH DATA
frames=[latlon_south,latlon_north]
df= pd.concat(frames)
df
# Out:
#          lat       lon   temp  cloud  wind  humidity
# 0    -8.7386   24.9906  18.87    100  0.99        92
# 1    -7.9562   38.9716  24.01     88  1.37        94
# 2   -21.1500  149.2000  31.49     43  4.63        55
# 3   -23.1203 -134.9692  26.74     93  5.05        74
# 4     5.4112  100.3354  26.06     20  1.54        73
# ..       ...       ...    ...    ...   ...       ...
# 466  15.0000  -90.3518  25.10      0  3.82        80
# 467  64.3833  -90.3518 -11.62    100  7.62        91
# 468  46.4856  -90.3518  -5.99    100  3.93        96
# 469  22.0752  -90.3518  25.43     40  4.12        69
# 470  37.7333  -90.3518  14.44     20  9.77        72
#
# [937 rows x 6 columns]

# %%
#SECTION III: SCATTERPLOTS
# Build a scatter plot for each data type
lat_xvalues = df['lat']

# %%
#TEMPERATURE

temp_yvalues = df['temp']
plt.scatter(lat_xvalues,temp_yvalues)

# Incorporate the other graph properties
plt.title("Temperature vs Latitude")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Temperaturevslat.png")

# Show plot
plt.show()


# TEMPERATURE IS HIGHER BELOW THE EQUATOR

# %%
# CLOUDINESS

cloud_yvalues = df['cloud']
plt.scatter(lat_xvalues,cloud_yvalues)

# Incorporate the other graph properties
plt.title("Cloudiness vs Latitude")
plt.ylabel("cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("cloudinesslat.png")

# Show plot
plt.show()

# CLOUDINESS has no clear tendency

# %%
# WIND

wind_yvalues = df['wind']
plt.scatter(lat_xvalues,wind_yvalues)

# Incorporate the other graph properties
plt.title("Wind vs Latitude")
plt.ylabel("wind")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("windlat.png")

# Show plot
plt.show()

# CLOUDINESS has no clear tendency within latitudes

# %%
#SECTION IV LINEAR REGRESSIONS

# %%
#1 Northern Hemisphere - Temperature (F) vs. Latitude

nax_values = latlon_north['lat']  #
nby_values = latlon_north['temp']  #

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(nax_values, nby_values)

# Get regression values
regress_values_one = nax_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(nax_values,nby_values)
plt.plot(nax_values,regress_values_one,"r-")

# Label plot nd annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()

#--> negative correlation more latitude, less temperature
# Out:
# The r-value is: 0.6412930907972473

# %%
#2 Southern Hemisphere - temperature (%) vs. Latitude

sax_values = latlon_south['lat'] #
sby_values = latlon_south['temp'] #

 #Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(sax_values, sby_values)

# Get regression values
regress_values_one = sax_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(sax_values,sby_values)
plt.plot(sax_values,regress_values_one,"r-")

# Label plot nd annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()

#--> negative correlation less latitude, more temperature
# Out:
# The r-value is: 0.24338920667471658

# %%
#3 Northern Hemisphere - Cloudiness (%) vs. Latitude

ncx_values = latlon_north['lat']
ndy_values = latlon_north['cloud']


#ncx_values = weather_data_II['lat']
#ndy_values = weather_data_II['cloud']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(ncx_values, ndy_values)

# Get regression values
regress_values_three = ncx_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(ncx_values,ndy_values)
plt.plot(ncx_values,regress_values_three,"r-")

# Label plot nd annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('cloudiness')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()

#--> negative correlation less latitude, more temperature, altough r .04 no significance
# Out:
# The r-value is: 0.027464516239538196

# %%
#4 Southern Hemisphere - Cloudiness (%) vs. Latitude

scx_values = latlon_south['lat']#
sdy_values = latlon_south['cloud']#

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(scx_values, sdy_values)

# Get regression values
regress_values_four = scx_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(scx_values,sdy_values)
plt.plot(scx_values,regress_values_four,"r-")

# Label plot nd annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('cloudiness')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()


#--> no significance r .03
# Out:
# The r-value is: 0.05216657795697349

# %%
#5 Northern Hemisphere - Wind Speed (mph) vs. Latitude


nfx_values = latlon_north['lat']
ngy_values = latlon_north['wind']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(nfx_values, ngy_values)

# Get regression values
regress_values_NHWL = nfx_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(nfx_values,ngy_values)
plt.plot(nfx_values,regress_values_NHWL,"r-")

# Label plot nd annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('wind')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()

#vast mayority of the sample is below 7.5
# Out:
# The r-value is: 0.019394011608025657

# %%
#6 Southern Hemisphere - Wind Speed (mph) vs. Latitude


sfx_values = latlon_south['lat']
sgy_values = latlon_south['wind']


# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(sfx_values, sgy_values)

# Get regression values
regress_values_SHWL = sfx_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(sfx_values,sgy_values)
plt.plot(sfx_values,regress_values_SHWL,"r-")

# Label plot nd annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('wind')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()

#in this sample, more disperse the velocities
# Out:
# The r-value is: 0.022519468285616902

# %%
#7 Northern Hemisphere - Humidity (%) vs. Latitude

nfx_values = latlon_north['lat']
wind_valuesN = latlon_north['humidity']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(nfx_values, wind_valuesN)

# Get regression values
regress_values_NHHL = nfx_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(nfx_values,wind_valuesN)
plt.plot(nfx_values,regress_values_NHHL,"r-")

# Label plot nd annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('humidity')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()

#positive correlation, more latitude more humidity
# Out:
# The r-value is: 0.06024966003264311

# %%
#8 Southern Hemisphere - Humidity (%) vs. Latitude

sfx_values = latlon_south['lat']
wind_valuesS = latlon_south['humidity']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(sfx_values, wind_valuesS)

# Get regression values
regress_values_SHHL = sfx_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(sfx_values,wind_valuesS)
plt.plot(sfx_values,regress_values_SHHL,"r-")

# Label plot nd annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.0026757414950319513

# %%
# Part II - VacationPy

# %%
#SECTION 1 : HEAT MAP
#Create a heat map that displays the humidity for every city from Part I.
import gmaps
# Google developer API key
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)

locations= df[["lat","lon"]]
humidities= df["humidity"]

# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=humidities, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=10)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#SECTION 2: FIND IDEAL CONDITIONS 
#Narrow down the DataFrame to find your ideal weather condition. For example:#A max temperature lower than 80 degrees but higher than 70.Wind speed less than 10 mph.Drop any rows that don't contain all three conditions. You want to be sure the weather is ideal.

selected_cities=df.loc[df["temp"] >= 30]
selected_cities
 
#find names of cities
# Out:
#          lat       lon   temp  cloud  wind  humidity
# 2   -21.1500  149.2000  31.49     43  4.63        55
# 8   -21.2000 -175.2000  30.00     20  4.63        74
# 12  -24.8667  113.6333  30.00     75  3.09        79
# 32  -24.8667  113.6333  30.00     75  3.09        79
# 33  -19.5500  169.2667  30.00     40  3.60        74
# 58  -20.3167  118.5667  30.00     40  4.63        62
# 65  -24.8667  113.6333  30.00     75  3.09        79
# 68  -19.5500  169.2667  30.00     40  3.60        74
# 148 -19.5500  169.2667  30.00     40  3.60        74
# 149 -19.0595 -169.9187  31.00      5  3.60        66
# 175 -24.8667  113.6333  30.00     75  3.09        79
# 190 -24.8667  113.6333  30.00     75  3.09        79
# 191  -6.7221  146.9847  31.08     94  2.48        58
# 192  -5.5502  150.1429  30.17     83  1.17        65
# 210 -12.2333  136.7667  31.00     75  5.14        70
# 225 -24.8667  113.6333  30.00     75  3.09        79
# 266  -5.5502  150.1429  30.17     83  1.17        65
# 345 -21.2000 -175.2000  30.00     20  4.63        74
# 358 -24.8667  113.6333  30.00     75  3.09        79
# 364 -21.2000 -175.2000  30.00     20  4.63        74
# 390 -21.2000 -175.2000  30.00     20  4.63        74
# 407 -21.2000 -175.2000  30.00     20  4.63        74
# 418  -7.9631  145.7785  30.05    100  2.40        61
# 423 -12.2333  136.7667  31.00     75  5.14        70
# 424 -24.8667  113.6333  30.00     75  3.09        79
# 439 -21.2000 -175.2000  30.00     20  4.63        74
# 448 -16.9167  145.7667  30.07    100  2.57        70
# 456 -24.8667  113.6333  30.00     75  3.09        79
# 458 -15.7667  128.7333  30.00     75  4.12        79

# %%
#SECTION 3: SEARCH FOR HOTEL


#MARKERS
coordinates=[(-21.15,149.2),
(-21.2,-175.2),
(-24.8667,113.6333),
(-24.8667,113.6333),
(-19.55,169.2667),
(-20.3167,118.5667),
(-24.8667,113.6333),
(-19.55,169.2667),
(-19.55,169.2667),
(-19.0595,-169.9187),
(-24.8667,113.6333),
(-24.8667,113.6333),
(-6.7221,146.9847),
(-5.5502,150.1429),
(-12.2333,136.7667),
(-24.8667,113.6333),
(-5.5502,150.1429),
(-21.2,-175.2),
(-24.8667,113.6333),
(-21.2,-175.2),
(-21.2,-175.2),
(-21.2,-175.2),
(-7.9631,145.7785),
(-12.2333,136.7667),
(-24.8667,113.6333),
(-21.2,-175.2),
(-16.9167,145.7667),
(-24.8667,113.6333),
(-15.7667,128.7333)]

# Customize the size of the figure
figure_layout = {
    'width': '400px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}

# Assign the marker layer to a variable
markers = gmaps.marker_layer(coordinates)

figtwo = gmaps.figure(layout=figure_layout)
# Add the layer to the map
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Using Google Places API to find the first hotel for each city located within 5000 meters of your coordinates.


# geocoordinates
target_coordinates = "-21.15,149.2","-21.2,-175.2"
target_search = "hotel"
target_radius = 5000


# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)
response.json()
# Out:
# {'html_attributions': [],
#  'next_page_token': 'ATtYBwJauNQFBKPQlNXhcTDtP2mH4FnHVYqDd-IKtaiemtw26_sN4ZKbKQlaRWKM9Hdqq3RO2QYxtLKKRgVIo8JK0T-XeloFA8mafUkYBjZFsJGLesvGO6GmyBjlKC2ru1--H5sbwR-BfP7UlcDQwQpGiGdTxSHfUDTVad54WkW1N1B-qx85tqhhI2kkMC8x0YB8KrQMjeKv9wonXjXzriGKLCP5hE-xC4H5T1ZvuK5qIgT0Y7YhpSe64rkVubee2MgMJO5aiTfwFGxNXkkYd-jCEdsHktbs6v6omL_Atc61g1lJMyRKd_G-u-ATjoYogmBC6rO2LQ4AVMGM0gKIwm5KzXb9zahMxtLxILK0kOcEPzbo85ZJIAsZjqehWhcHYlo5Qqczd05Rq996WNZPlJszozdkBd40mUHhyt1UUYoTFjRagiiJMD4h2g',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.1120683, 'lng': 149.2240027},
#     'viewport': {'northeast': {'lat': -21.11062282010728,
#       'lng': 149.2249849798927},
#      'southwest': {'lat': -21.11332247989272, 'lng': 149.2222853201073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Mantra Mackay',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3496,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100188637786374668447">Clarion Hotel Mackay Marina</a>'],
#      'photo_reference': 'ATtYBwLY_UPYmIzCTF1ePM_AycyAebT5ryU4cyDoOakLCgwD2TCsrlsIJEhdWdqf0CJB2mLa7OLc79v8lMalPikKxbRmBS3Dc9BRM9USOIamalcj8h4hrjixbqfXC9mmXMlQg1BOuKlS6ThBiOqXidllSO-lAkNI2ttd3RiPUNqImT-6WUiS',
#      'width': 5244}],
#    'place_id': 'ChIJPXvOtvPW22sRHVAWBr3owY8',
#    'plus_code': {'compound_code': 'V6QF+5J Mackay, Queensland, Australia',
#     'global_code': '5RCFV6QF+5J'},
#    'rating': 4.3,
#    'reference': 'ChIJPXvOtvPW22sRHVAWBr3owY8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 356,
#    'vicinity': 'Mulherin Dr, Mackay'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.1646092, 'lng': 149.1962497},
#     'viewport': {'northeast': {'lat': -21.16311097010728,
#       'lng': 149.1976175298927},
#      'southwest': {'lat': -21.16581062989272, 'lng': 149.1949178701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Ocean International Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1365,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100629546524143720049">A Google User</a>'],
#      'photo_reference': 'ATtYBwIo6cRqdYg_1pvRXr8kWdq5PFOQbrLVx62JRxvP9Drp6jctp_uyaGy63GdtoTAtGBJSR2G-GJjGKTm_d2ZdOd1MDcttT3x2mtDz7tnaobAiZaJghG8g9_i2woho6qwrujbaFh2V959CptPrrudGGP24V67THfyHI7UFk6GwIvQkSg8w',
#      'width': 2048}],
#    'place_id': 'ChIJLcyIHGDR22sRPis0YSx4pPE',
#    'plus_code': {'compound_code': 'R5PW+5F Mackay, Queensland, Australia',
#     'global_code': '5RCFR5PW+5F'},
#    'rating': 4.4,
#    'reference': 'ChIJLcyIHGDR22sRPis0YSx4pPE',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'lodging',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 188,
#    'vicinity': '1 Bridge Rd, Mackay'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.1472855, 'lng': 149.1721435},
#     'viewport': {'northeast': {'lat': -21.14606427010728,
#       'lng': 149.1736444798927},
#      'southwest': {'lat': -21.14876392989272, 'lng': 149.1709448201073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Coral Cay Resort',
#    'photos': [{'height': 1000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107560417173360078683">A Google User</a>'],
#      'photo_reference': 'ATtYBwJrNy2JRb5Dynssg4FWPMApr0er1bNP4-eI0gZaYVVr1MnNfGJXk5QlezS28uB5qQNlNQfsMIBbO1gOZZm3J9YV80BzovhPMfBFlE3KQtlESBeCCjjskC6rLhypCn52bKbVREf-Leg3K9XcD_QeMN5NxPdc0IuN3J_897fzGlyfkTut',
#      'width': 1500}],
#    'place_id': 'ChIJ_TUlQo3T22sRGfyPVrIY-Nk',
#    'plus_code': {'compound_code': 'V53C+3V Mackay, Queensland, Australia',
#     'global_code': '5RCFV53C+3V'},
#    'rating': 4.1,
#    'reference': 'ChIJ_TUlQo3T22sRGfyPVrIY-Nk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 231,
#    'vicinity': '14 Nebo Rd, Mackay'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.148159, 'lng': 149.2021942},
#     'viewport': {'northeast': {'lat': -21.14689672010728,
#       'lng': 149.2034765298927},
#      'southwest': {'lat': -21.14959637989272, 'lng': 149.2007768701072}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Mackay Oceanside Central Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 540,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118365494730000475356">A Google User</a>'],
#      'photo_reference': 'ATtYBwJAdlhLjMNgbu2_0M-hsJOGtwCSb4MaX6eC8pr-TEZwUNT8r57_MWzPs25X7DyNDsZkfwbhHs5NiRB6nBcwOSwsY4U_37Gbn-LJHxw9E7GnalbK2yCup-IW7228_QfU5WZIyZ4xET9SCgSOoxlkhqI7ZPY50OeU6Nq-PP1_JfiPm7Iv',
#      'width': 800}],
#    'place_id': 'ChIJy60seFXR22sReRKgkt6b_cI',
#    'plus_code': {'compound_code': 'V622+PV Mackay, Queensland, Australia',
#     'global_code': '5RCFV622+PV'},
#    'rating': 4.5,
#    'reference': 'ChIJy60seFXR22sReRKgkt6b_cI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 120,
#    'vicinity': '2C, E Gordon St, Mackay'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.1438078, 'lng': 149.1886144},
#     'viewport': {'northeast': {'lat': -21.14240997010728,
#       'lng': 149.1899717798927},
#      'southwest': {'lat': -21.14510962989272, 'lng': 149.1872721201073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Quest Mackay on Gordon',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1365,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101927051983340581128">Quest Mackay on Gordon</a>'],
#      'photo_reference': 'ATtYBwID0r15XvCmfeTm9xFQHaw1wKsXhrY8GGfW9OrMvBGBuj6YxHLzuWRGjhCg2wVf0nE14QHepwDPXHds6f7U-zS480ss5tvflO3jJ-nlf_i2dkDZrjIpLuRTImnSe7AFvvWR8-mXApieaCzmf40DnTVy146I_wZRSrH5wstXxcqepjGq',
#      'width': 2048}],
#    'place_id': 'ChIJR4-rHvnT22sRL9q4jl84E-o',
#    'plus_code': {'compound_code': 'V54Q+FC Mackay, Queensland, Australia',
#     'global_code': '5RCFV54Q+FC'},
#    'rating': 4.4,
#    'reference': 'ChIJR4-rHvnT22sRL9q4jl84E-o',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 146,
#    'vicinity': '27 Gordon St, Mackay'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.1388205, 'lng': 149.1826588},
#     'viewport': {'northeast': {'lat': -21.13740432010728,
#       'lng': 149.1840198298927},
#      'southwest': {'lat': -21.14010397989272, 'lng': 149.1813201701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Oaks Mackay Rivermarque Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 400,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105308836528060281929">Oaks Rivermarque Mackay</a>'],
#      'photo_reference': 'ATtYBwIVfkU_1YKcSBhY5PUrzcKXRBV48OsKWmAj6vJUWoDF_x-Crw8TLfQCtwLTZb0Vp34hrW3OGjlrpDDav70378TZn2ZDtQpTpnuA-FHFr1MNTRPJrN-K1m08V9IfqndpaBxYq6REVuJgWav7uXXdy8NDeiNpJmSKn3letySK63K3yeaN',
#      'width': 600}],
#    'place_id': 'ChIJY1tsOQjU22sRsMZZHNuvpPc',
#    'plus_code': {'compound_code': 'V56M+F3 Mackay, Queensland, Australia',
#     'global_code': '5RCFV56M+F3'},
#    'rating': 4.1,
#    'reference': 'ChIJY1tsOQjU22sRsMZZHNuvpPc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 183,
#    'vicinity': '55/55-63 River St, Mackay'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.1441599, 'lng': 149.1897569},
#     'viewport': {'northeast': {'lat': -21.14265032010728,
#       'lng': 149.1911349298927},
#      'southwest': {'lat': -21.14534997989272, 'lng': 149.1884352701072}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Metropolitan Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114724920211059752736">Grahame Drysdale</a>'],
#      'photo_reference': 'ATtYBwIqVgcai7q7tml16p-lnT8ywNfFMB450ax1NM4LdX-XG0hwLJt1oyz4U-p0rvx7Cn4MMtLHC4ramGKgmrzNaSqFFAAffPkD3CRvOZjmsg9nnGbnubJfyFqEKERKeplhIZRPwxPaz-jRt_V3XP38UK6ujp5wkkxwHdcSyvwQXrh5pxq7',
#      'width': 4032}],
#    'place_id': 'ChIJkQCVKPnT22sRmBsIgsDG1e0',
#    'plus_code': {'compound_code': 'V54Q+8W Mackay, Queensland, Australia',
#     'global_code': '5RCFV54Q+8W'},
#    'rating': 4,
#    'reference': 'ChIJkQCVKPnT22sRmBsIgsDG1e0',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 169,
#    'vicinity': '17 Gordon St, Mackay'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.146195, 'lng': 149.189366},
#     'viewport': {'northeast': {'lat': -21.14469647010728,
#       'lng': 149.1908161298928},
#      'southwest': {'lat': -21.14739612989272, 'lng': 149.1881164701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Oaks Mackay Carlyle Suites',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4429,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110910113334337868219">Oaks Carlyle</a>'],
#      'photo_reference': 'ATtYBwIkMpM71noBx-_F-r39UveyJusDhJf2Nol-sfsCI0v5rK1BwGf2_wj1yfCJe8RUKjIIbfuRP4I93-xItRBkGgL-CayJVof0D7xao9_aeDEMTJA97dGfOvtnE4_pfIUOmQwQxZiCQLsFoF6Li1AYldor5m3omK67sFxy3a4S-ZeRk2M',
#      'width': 5906}],
#    'place_id': 'ChIJmSpwWfnT22sRZv7i_P59HWA',
#    'plus_code': {'compound_code': 'V53Q+GP Mackay, Queensland, Australia',
#     'global_code': '5RCFV53Q+GP'},
#    'rating': 4,
#    'reference': 'ChIJmSpwWfnT22sRZv7i_P59HWA',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 111,
#    'vicinity': '23 Alfred St, Mackay'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.1546207, 'lng': 149.1649211},
#     'viewport': {'northeast': {'lat': -21.15345277010728,
#       'lng': 149.1664883798927},
#      'southwest': {'lat': -21.15615242989272, 'lng': 149.1637887201073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Mackay Resort Motel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3767,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110860471937899831255">A Google User</a>'],
#      'photo_reference': 'ATtYBwIXrx_93O1NQ65jFAQkyuQzAv2T-mBAZ8UjZlyHRDSZZskQk947YgDDnQjsYAf4gM_XelwAVfnWRuUZVoo6v17qV8G5M9773PdZ8472wDAhQ4CwFflckEWoj0Ol7BWFmf-8pldFB7c4EwoIecsAcJsOHmSE1yUCWprdmXlbPFxyiag6',
#      'width': 7140}],
#    'place_id': 'ChIJC781-pbT22sRwPETnurtJyY',
#    'plus_code': {'compound_code': 'R5W7+5X Mackay, Queensland, Australia',
#     'global_code': '5RCFR5W7+5X'},
#    'rating': 4.5,
#    'reference': 'ChIJC781-pbT22sRwPETnurtJyY',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 97,
#    'vicinity': '154 Nebo Rd, Mackay'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.1656627, 'lng': 149.1555786},
#     'viewport': {'northeast': {'lat': -21.16424972010728,
#       'lng': 149.1568543298927},
#      'southwest': {'lat': -21.16694937989272, 'lng': 149.1541546701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Boomerang Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103226018189088513273">Craig Simpson</a>'],
#      'photo_reference': 'ATtYBwL-VfdtDlA08ewTVRrSPFwlaaQ5f-1NKYK5WLbNIOFXVwcfHcwp0bSODgO4t65TuTV1aU_Gk5b9-bDNYwqh_n4OtTiyNULG_RlkA60cBAkWZQPVBOvnQhNLjgNotK49EsR0dbBLx_Xj2-wcHHSTwrbeCn42aXuq4JcETn_t9HhIHgs9',
#      'width': 4032}],
#    'place_id': 'ChIJdfO846XT22sRZR5YNYhYopY',
#    'plus_code': {'compound_code': 'R5M4+P6 Mackay, Queensland, Australia',
#     'global_code': '5RCFR5M4+P6'},
#    'rating': 3.8,
#    'reference': 'ChIJdfO846XT22sRZR5YNYhYopY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 170,
#    'vicinity': '307 Nebo Rd, Mackay'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.1417446, 'lng': 149.1855163},
#     'viewport': {'northeast': {'lat': -21.14052572010728,
#       'lng': 149.1863870298927},
#      'southwest': {'lat': -21.14322537989272, 'lng': 149.1836873701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Rydges Mackay Suites',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3416,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113887981000586250968">A Google User</a>'],
#      'photo_reference': 'ATtYBwK1JVPOnWEIaeO-KE8WbBl2Vm2fhj368BlM_0ZZgH_fr3JWKldihhY34sbH-5hC-XiUYkJfC0iq4qaqVSjLDejPbLP4EMlcP4Ln5Q9KncpOYrQ7kToNa6Kxj7At1m6xp2WS0s5BbWj0umM-vlBBNCcf0Uni5yv_Ytv7PaY91PsQC0jP',
#      'width': 5124}],
#    'place_id': 'ChIJj25uJ_jT22sR_C-WNf4_0b8',
#    'plus_code': {'compound_code': 'V55P+86 Mackay, Queensland, Australia',
#     'global_code': '5RCFV55P+86'},
#    'rating': 4,
#    'reference': 'ChIJj25uJ_jT22sR_C-WNf4_0b8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 236,
#    'vicinity': '9 Gregory St, Mackay'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.1381594, 'lng': 149.1834877},
#     'viewport': {'northeast': {'lat': -21.13682007010728,
#       'lng': 149.1849481298927},
#      'southwest': {'lat': -21.13951972989273, 'lng': 149.1822484701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Mid City Motor Inn',
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113334037696073080821">Jordan Wright</a>'],
#      'photo_reference': 'ATtYBwLImCAsFlHGGEjFA8hPrL0kJt08QxkEYg-3KOJ3pjs6u0ON3aWwKwWJfW-Q0UOPW673W8tl0yM8pIW1vsB8sXQut4JHURt_t9h7rqKTLhoIFxb3zQOXESv6oS9JOuL-hzUsu422nJzO_kvQQfwrpwyEwprmAwtF_lCoURig7-bbGd05',
#      'width': 1620}],
#    'place_id': 'ChIJp5GhFgjU22sRJ-1BC9wXm8I',
#    'plus_code': {'compound_code': 'V56M+P9 Mackay, Queensland, Australia',
#     'global_code': '5RCFV56M+P9'},
#    'rating': 4.2,
#    'reference': 'ChIJp5GhFgjU22sRJ-1BC9wXm8I',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 129,
#    'vicinity': '2A MacAlister St, Mackay'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.1559678, 'lng': 149.1648756},
#     'viewport': {'northeast': {'lat': -21.15454362010728,
#       'lng': 149.1661352298927},
#      'southwest': {'lat': -21.15724327989272, 'lng': 149.1634355701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Shamrock Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3648,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106988602110947462925">Shamrock Hotel</a>'],
#      'photo_reference': 'ATtYBwJW6qTvdKpwbTKp6s39vcZE2sihtMPUaNBhmr6FOUHbm_FNbufOPxHYVTnt1jZsXHLziF1fNDQic8K23-0Y88q4x4DkTjkdzwNcPkiD6jhA5cWi3_RVR0i9ep_VxY7K4NkLy1FEL_tJ5DFYY85Wq37HY6l5VWwrROAPVoel8vVfRUAf',
#      'width': 5472}],
#    'place_id': 'ChIJgc4jTpbT22sRWnAc8eaqoz0',
#    'plus_code': {'compound_code': 'R5V7+JX Mackay, Queensland, Australia',
#     'global_code': '5RCFR5V7+JX'},
#    'rating': 4.3,
#    'reference': 'ChIJgc4jTpbT22sRWnAc8eaqoz0',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'bar',
#     'liquor_store',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 624,
#    'vicinity': '165 Nebo Rd, Mackay'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.1414237, 'lng': 149.1831836},
#     'viewport': {'northeast': {'lat': -21.14005352010728,
#       'lng': 149.1845623298927},
#      'southwest': {'lat': -21.14275317989272, 'lng': 149.1818626701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Quest Mackay',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113857399991551151274">Quest Mackay</a>'],
#      'photo_reference': 'ATtYBwIIY18rZWhCcHNvyjJ7oqPaxnD9jqM-2NJnVa22_VJmUcBor6AUGUMG6c66Wyma2aGiqD5fELo-2D4QyrT9Iw-10SNXh7NMIRq_abXEZZhsUifwtbMKZXc523J41N0Jp391uZ85WNcxu_gVZ7H24Y-tPjIRbShBbU_pvaWG6YXgJCrx',
#      'width': 2002}],
#    'place_id': 'ChIJiafwvvfT22sREd_FTEbFLek',
#    'plus_code': {'compound_code': 'V55M+C7 Mackay, Queensland, Australia',
#     'global_code': '5RCFV55M+C7'},
#    'rating': 4.2,
#    'reference': 'ChIJiafwvvfT22sREd_FTEbFLek',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 92,
#    'vicinity': '38 MacAlister St, Mackay'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.176551, 'lng': 149.181276},
#     'viewport': {'northeast': {'lat': -21.17510452010728,
#       'lng': 149.1825556298927},
#      'southwest': {'lat': -21.17780417989272, 'lng': 149.1798559701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'ibis Mackay',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 768,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103754107705878382052">Hotel ibis Mackay Airport</a>'],
#      'photo_reference': 'ATtYBwLtiBjCMefocbMGZXSDBayTwu1cN-MyC9yi55dVafiATvHypb66wkOUK3p1VR54iLY_KbbMkpH6C8J5t-udC0TLutPP70ma2p8275MCiAbS-uKuIYop12gerN2QFPmbvCuBxEBUYsfSpDqrLU2jt4emkXuTDT_CgNTdad74P61q_IP1',
#      'width': 1024}],
#    'place_id': 'ChIJGcUmUs_T22sR6SvDPt6P_so',
#    'plus_code': {'compound_code': 'R5FJ+9G Mackay, Queensland, Australia',
#     'global_code': '5RCFR5FJ+9G'},
#    'rating': 4.2,
#    'reference': 'ChIJGcUmUs_T22sR6SvDPt6P_so',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 307,
#    'vicinity': 'Mackay Airport, Christensen Circuit, Mackay'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.1257061, 'lng': 149.1571673},
#     'viewport': {'northeast': {'lat': -21.12430777010728,
#       'lng': 149.1585238798927},
#      'southwest': {'lat': -21.12700742989272, 'lng': 149.1558242201072}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Windmill Motel and Events Centre',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 313,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105918325360723437447">Windmill Motel and Reception Centre</a>'],
#      'photo_reference': 'ATtYBwLYq-bOU1lorwMOo_RE8Rc0jxa-h1-RQle8WfiFJwc3520bbW3hndE3XDdZvcsqZEoR6Z8sOLxFpuFyM8WNxk9mzf4I43wESBCvBvXTvTCutd4t21lZa4CSy_u182v8xpQeWlw3jALSxcBCd7oAJhJUMVNdO71t009OMoXo0Un9UOCy',
#      'width': 391}],
#    'place_id': 'ChIJ09NEFHvU22sR8-y_yD1KWEw',
#    'plus_code': {'compound_code': 'V5F4+PV Mackay, Queensland, Australia',
#     'global_code': '5RCFV5F4+PV'},
#    'rating': 4.2,
#    'reference': 'ChIJ09NEFHvU22sR8-y_yD1KWEw',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 145,
#    'vicinity': '5 Highway Plaza, Mackay'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.1416126, 'lng': 149.1829016},
#     'viewport': {'northeast': {'lat': -21.14028172010728,
#       'lng': 149.1844052298927},
#      'southwest': {'lat': -21.14298137989272, 'lng': 149.1817055701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'International Lodge Motel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1356,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118276499903253980607">International Lodge Motel</a>'],
#      'photo_reference': 'ATtYBwLaWqIpFIgLDd0md5KOt1l_YiGfK5yN-86AZfooYifQVFYs1eKSu_qnGpMLGIBA2bTRMBwQP9ZrPwNpjzrC7tbhGK5WtSzyVXpWSm1FZzNKFlWTV6IVhPtKBrF5sUFgeV73Rkcuwbahh0NC8unDoJTAqLLavv4s4k3STQYyaKDHmT8l',
#      'width': 2048}],
#    'place_id': 'ChIJ40CTvffT22sR4tAVDDczbSs',
#    'plus_code': {'compound_code': 'V55M+95 Mackay, Queensland, Australia',
#     'global_code': '5RCFV55M+95'},
#    'rating': 4.6,
#    'reference': 'ChIJ40CTvffT22sR4tAVDDczbSs',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 82,
#    'vicinity': '40 MacAlister St, Mackay'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.1419852, 'lng': 149.1830304},
#     'viewport': {'northeast': {'lat': -21.14064332010728,
#       'lng': 149.1844447798927},
#      'southwest': {'lat': -21.14334297989272, 'lng': 149.1817451201073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Coral Sands Motel',
#    'photos': [{'height': 9248,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112636051992721702742">A Google User</a>'],
#      'photo_reference': 'ATtYBwL4Pv1oADU5hES4GpcmAsgGD11XxEHKO0TelZmEVmXSHz2Adu4XKHqhL8VlUzr79HZIEap46ZyvpG1CJVra6Oa_qRXQMQTIlEHeS0nVZSTst_O4SCnTf-lcELiu2GIFJ5rA_Jaja8T1ugOzWOpmTj0ptJqu_Zo2MDirpgiqYBaOxpz6',
#      'width': 6936}],
#    'place_id': 'ChIJaafuovfT22sRfVw04W0PAJU',
#    'plus_code': {'compound_code': 'V55M+66 Mackay, Queensland, Australia',
#     'global_code': '5RCFV55M+66'},
#    'rating': 3.8,
#    'reference': 'ChIJaafuovfT22sRfVw04W0PAJU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 94,
#    'vicinity': '44 MacAlister St, Mackay'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.1486168, 'lng': 149.1712018},
#     'viewport': {'northeast': {'lat': -21.14732137010728,
#       'lng': 149.1726185298928},
#      'southwest': {'lat': -21.15002102989272, 'lng': 149.1699188701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Casa Nostra Motel Mackay',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1181,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103985817467481167187">A Google User</a>'],
#      'photo_reference': 'ATtYBwIk1mzmk3VLp3v4LHlnNabNVRZNB76gNm9m39QRgKqFvGQLTi3PVR8xjXt9RrdX5yJNpE4tDadEvcW5XqRKM8kXpoAQYjPEDG6A6B8IJIuyo_jWMyhnFtKQxBOHOUa3ekfxk6AIr5SCsBzbBai63CrYUFbT7MmSANF0msqWStxL9_Fd',
#      'width': 2592}],
#    'place_id': 'ChIJ-VlLmpLT22sR_TKG0ROYBN4',
#    'plus_code': {'compound_code': 'V52C+HF Mackay, Queensland, Australia',
#     'global_code': '5RCFV52C+HF'},
#    'rating': 4.4,
#    'reference': 'ChIJ-VlLmpLT22sR_TKG0ROYBN4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 51,
#    'vicinity': '30 Nebo Rd, Mackay'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.138086, 'lng': 149.182083},
#     'viewport': {'northeast': {'lat': -21.13694647010728,
#       'lng': 149.1834016798927},
#      'southwest': {'lat': -21.13964612989272, 'lng': 149.1807020201072}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Lanai Riverside Apartments Mackay Accommodation',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4912,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102024740259465872104">Lanai Riverside Apartments Mackay Accommodation</a>'],
#      'photo_reference': 'ATtYBwIfJumG_VhFrhFSpdIFSJ_NyPsc_48H72SjxnrO3DN2_fTNKuLNMrxNF_iHHncsMPmiP3r-OH7JMcGsZft-r6-Ugp-RI3jV-dCN25K0VQPoinvdFEaJ6sCJkw1E3gt8FiAsiRlz7RG1E4YhWGvt8KVrolX4kvaLODvvxXtRPwXzMj9E',
#      'width': 7360}],
#    'place_id': 'ChIJF0MgTQfU22sRFrv-ayeFh34',
#    'plus_code': {'compound_code': 'V56J+QR Mackay, Queensland, Australia',
#     'global_code': '5RCFV56J+QR'},
#    'rating': 3.9,
#    'reference': 'ChIJF0MgTQfU22sRFrv-ayeFh34',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 11,
#    'vicinity': '20 River St, Mackay'}],
#  'status': 'OK'}

# %%
#SECTION 4: HOTELS & HUMIDITY
#Plot the hotels on top of the humidity heatmap with each pin containing the Hotel Name, City, and Country.

# %%
hotel_layer=gmaps.heatmap_layer(response, weights=rating, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)
# Add layer
fig.add_layer(heat_layer,hotel_layer)
